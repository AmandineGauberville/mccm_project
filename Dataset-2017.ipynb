# %% [markdown]
# # Constitution du dataset à partir des données exportées de CEGID expert

# %% [markdown]
# Dossiers exportés :
# - Missions du cabinet sur 2017
# - Facturation 2017
# - Entrées et sorties des clients

# %% [markdown]
# ## Importation des librairies

# %%
import pandas as pd
import numpy as np
import re
from scipy import stats

# %% [markdown]
# ## Lecture de l'ensemble des missions du cabinet sur 2020
# 1 ligne = 1 mission réalisée par 1 assistant pour le compte d'un client

# %%
missions = pd.read_csv("./Data/missions_2017.txt", sep="\t", decimal='.')

# %%
missions.head(10)
# Out:
#         Code Mission Mission  Exercice Client          Raison sociale  \
# 0  AJUR2017007869600     JUR      2017  06796       BV VAL DES MAUVES
# 1  AJUR2017007869600     JUR      2017  06796       BV VAL DES MAUVES
# 2  ACOM2017008248000     COM      2017  05955            CROC EXPRESS
# 3  ACOM2017008333700     COM      2017  06834         ORLANDO GENNARO
# 4  ACOM2017008310700     COM      2017  02395                  BETMON
# 5  AJUR2017008549700     JUR      2017  07001  LOUIS DES P'TITS PLATS
# 6  AJUR2017008201000     JUR      2017  77260                G.A.E.L.
# 7  AJUR2017008201000     JUR      2017  77260                G.A.E.L.
# 8  ACOM2017008303800     COM      2017  06671             ICOLE-DUMAS
# 9  AJUR2017008201000     JUR      2017  77260                G.A.E.L.
#
#    DEPART CLIENT Assistant ASSOCIES/EC Article  \
# 0            NaN       335         DAC     069
# 1            NaN       335         DAC     060
# 2            1.0       664         DAC     021
# 3            NaN       271         FRL     020
# 4            NaN       271         FRL     021
# 5            4.0       666         VAL     060
# 6            NaN       340         JOP     060
# 7            NaN       666         JOP     060
# 8            NaN       271         SLE     020
# 9            NaN       340         JOP     069
#
#                                     Libellé Qté activité Prix de vente  \
# 0                          DIVERS JURIDIQUE         0,25         54,00
# 1              SECRETARIAT JURIDIQUE ANNUEL         0,50         56,00
# 2  DECLARATIONS MENSUELLES / TRIMESTRIELLES         0,50         72,00
# 3                             FICHE DE PAIE         0,50         56,00
# 4  DECLARATIONS MENSUELLES / TRIMESTRIELLES         0,50         56,00
# 5              SECRETARIAT JURIDIQUE ANNUEL         0,25         56,00
# 6              SECRETARIAT JURIDIQUE ANNUEL         1,25         66,00
# 7              SECRETARIAT JURIDIQUE ANNUEL         0,25         56,00
# 8                             FICHE DE PAIE         1,25         56,00
# 9                          DIVERS JURIDIQUE         0,25         66,00
#
#   Total  de vente Département             SITE  Unnamed: 15
# 0           13,50         JUR  MEUNG SUR LOIRE          NaN
# 1           28,00         JUR  MEUNG SUR LOIRE          NaN
# 2           36,00       SOCSJ  MEUNG SUR LOIRE          NaN
# 3           28,00       SOCSJ     CLIENT PARTI          NaN
# 4           28,00       SOCSJ     CLIENT PARTI          NaN
# 5           14,00         JUR             GIEN          NaN
# 6           82,50         JUR     CLIENT PARTI          NaN
# 7           14,00         JUR     CLIENT PARTI          NaN
# 8           70,00       SOCSJ           OLIVET          NaN
# 9           16,50         JUR     CLIENT PARTI          NaN

# %%
#Le dataset des missions 2017 contient 257 838 entrées et 16 colonnes
missions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257838 entries, 0 to 257837
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Code Mission     257838 non-null  object
#  1   Mission          257838 non-null  object
#  2   Exercice         257838 non-null  int64
#  3   Client           257838 non-null  object
#  4   Raison sociale   257838 non-null  object
#  5   DEPART CLIENT    62485 non-null   float64
#  6   Assistant        257838 non-null  object
#  7   ASSOCIES/EC      257838 non-null  object
#  8   Article          257838 non-null  object
#  9   Libellé          257838 non-null  object
#  10  Qté activité     257838 non-null  object
#  11  Prix de vente    257838 non-null  object
#  12  Total  de vente  257838 non-null  object
#  13  Département      238346 non-null  object
#  14  SITE             257838 non-null  object
#  15  Unnamed: 15      0 non-null       float64
# dtypes: float64(2), int64(1), object(13)
# memory usage: 31.5+ MB

# %%
missions.columns
# Out:
# Index(['Code Mission', 'Mission', 'Exercice', 'Client', 'Raison sociale',
#        'DEPART CLIENT', 'Assistant', 'ASSOCIES/EC', 'Article', 'Libellé',
#        'Qté activité', 'Prix de vente', 'Total  de vente', 'Département',
#        'SITE', 'Unnamed: 15'],
#       dtype='object')

# %%
#Supprimer la dernière colonne inutile
missions.drop(columns=['Département','Unnamed: 15'], inplace=True)

# %%
missions.columns = ['code_mission','mission','exercice','code_client',
                    'client','depart_client','code_assistant','manager','code_article',
                    'libelle_article','temps','cout_horaire','valorisation_temps','site']

# %%
missions.dtypes
# Out:
# code_mission           object
# mission                object
# exercice                int64
# code_client            object
# client                 object
# depart_client         float64
# code_assistant         object
# manager                object
# code_article           object
# libelle_article        object
# temps                  object
# cout_horaire           object
# valorisation_temps     object
# site                   object
# dtype: object

# %%
missions.isna().sum()
# Out:
# code_mission               0
# mission                    0
# exercice                   0
# code_client                0
# client                     0
# depart_client         195353
# code_assistant             0
# manager                    0
# code_article               0
# libelle_article            0
# temps                      0
# cout_horaire               0
# valorisation_temps         0
# site                       0
# dtype: int64

# %% [markdown]
# ## Modifier les colonnes catégorielles en float

# %%
#Remplacer les virgules par des points et espaces pour créer un nombre décimal
missions['temps'] = [x.replace(',', '.') for x in missions['temps']]
missions['temps'] = missions['temps'].astype(float)

# %%
missions['cout_horaire'] = [x.replace(',', '.') for x in missions['cout_horaire']]
missions['cout_horaire'] = [re.sub('\s','',x) for x in missions['cout_horaire']]
missions['cout_horaire'] = pd.to_numeric(missions['cout_horaire'])

# %%
missions['valorisation_temps'] = [x.replace(',', '.') for x in missions['valorisation_temps']]
missions['valorisation_temps'] = [re.sub('\s','',x) for x in missions['valorisation_temps']]
missions['valorisation_temps'] = pd.to_numeric(missions['valorisation_temps'])

# %%
missions
# Out:
#              code_mission mission  exercice code_client             client  \
# 0       AJUR2017007869600     JUR      2017       06796  BV VAL DES MAUVES
# 1       AJUR2017007869600     JUR      2017       06796  BV VAL DES MAUVES
# 2       ACOM2017008248000     COM      2017       05955       CROC EXPRESS
# 3       ACOM2017008333700     COM      2017       06834    ORLANDO GENNARO
# 4       ACOM2017008310700     COM      2017       02395             BETMON
# ...                   ...     ...       ...         ...                ...
# 257833  AGEJ2017010743500     GEJ      2017       06670          LA BUDANE
# 257834  AGEJ2017010743500     GEJ      2017       06670          LA BUDANE
# 257835  AGEJ2017010743500     GEJ      2017       06670          LA BUDANE
# 257836  AJUR2017008930300     JUR      2017       06702      AVENIR R ET R
# 257837  AGEJ2017010743500     GEJ      2017       06670          LA BUDANE
#
#         depart_client code_assistant manager code_article  \
# 0                 NaN            335     DAC          069
# 1                 NaN            335     DAC          060
# 2                 1.0            664     DAC          021
# 3                 NaN            271     FRL          020
# 4                 NaN            271     FRL          021
# ...               ...            ...     ...          ...
# 257833            NaN            965     SLE          069
# 257834            NaN            0R2     SLE          069
# 257835            NaN            0R2     SLE          069
# 257836            NaN            63P     SLE          060
# 257837            NaN            0R2     SLE          069
#
#                                  libelle_article  temps  cout_horaire  \
# 0                               DIVERS JURIDIQUE   0.25          54.0
# 1                   SECRETARIAT JURIDIQUE ANNUEL   0.50          56.0
# 2       DECLARATIONS MENSUELLES / TRIMESTRIELLES   0.50          72.0
# 3                                  FICHE DE PAIE   0.50          56.0
# 4       DECLARATIONS MENSUELLES / TRIMESTRIELLES   0.50          56.0
# ...                                          ...    ...           ...
# 257833                          DIVERS JURIDIQUE   0.25         165.0
# 257834                          DIVERS JURIDIQUE   1.00          58.5
# 257835                          DIVERS JURIDIQUE   0.50          58.5
# 257836              SECRETARIAT JURIDIQUE ANNUEL   1.00          76.5
# 257837                          DIVERS JURIDIQUE   0.50          58.5
#
#         valorisation_temps             site
# 0                    13.50  MEUNG SUR LOIRE
# 1                    28.00  MEUNG SUR LOIRE
# 2                    36.00  MEUNG SUR LOIRE
# 3                    28.00     CLIENT PARTI
# 4                    28.00     CLIENT PARTI
# ...                    ...              ...
# 257833               41.25          ORLEANS
# 257834               58.50          ORLEANS
# 257835               29.25          ORLEANS
# 257836               76.50           OLIVET
# 257837               29.25          ORLEANS
#
# [257838 rows x 14 columns]

# %% [markdown]
# ## Agrégation du dataframe sur le code_mission pour sommer le temps et la valorisation du temps

# %% [markdown]
# Il faut garder une version non aggrégée pour avoir :
# - les différents codes assistants par manager
# - Les différents sites
# - Les différents code_article et libellé articles (activités réalisées)

# %%
missions.code_mission.values
# Out:
# array(['AJUR2017007869600', 'AJUR2017007869600', 'ACOM2017008248000', ...,
#        'AGEJ2017010743500', 'AJUR2017008930300', 'AGEJ2017010743500'],
#       dtype=object)

# %%
missions_agg = missions.groupby(['code_mission']).agg({'mission':[lambda x:x.value_counts().index[0]],
                                                        'exercice':[lambda x:x.value_counts().index[0]],
                                                        'code_client': [lambda x:x.value_counts().index[0]],
                                                        'code_assistant': ['nunique'],
                                                        'manager': [lambda x:x.value_counts().index[0]],
                                                        'code_article': [lambda x: list(x.unique())],
                                                        'libelle_article': [lambda x: list(x.unique())],
                                                        'temps': ['sum'],
                                                        'valorisation_temps': ['sum'],
                                                        'site': [lambda x:x.value_counts().index[0]]})

# %%
missions_agg.head()
# Out:
#                    mission exercice code_client code_assistant  \
#                   <lambda> <lambda>    <lambda>        nunique
# code_mission
# AAGS2017010396900      AGS     2017       05782              2
# AAGS2017010397000      AGS     2017       06565              1
# AAGS2017010534300      AGS     2017       06924              2
# ACAB2017009616200      CAB     2017       09230             12
# ACAB2017009616300      CAB     2017       09000             98
#
#                           manager  \
#                          <lambda>
# code_mission
# AAGS2017010396900             JOP
# AAGS2017010397000             FRL
# AAGS2017010534300             JOP
# ACAB2017009616200  NON FACTURABLE
# ACAB2017009616300  NON FACTURABLE
#
#                                                         code_article  \
#                                                             <lambda>
# code_mission
# AAGS2017010396900                                              [029]
# AAGS2017010397000                                              [001]
# AAGS2017010534300                                    [029, 024, 001]
# ACAB2017009616200           [081, 096, 091, 079, 078, 082, 074, 088]
# ACAB2017009616300  [083, 082, 079, 096, 075, 010, 092, 080, 081, ...
#
#                                                      libelle_article    temps  \
#                                                             <lambda>      sum
# code_mission
# AAGS2017010396900                         [AUTRES TRAVAUX EN SOCIAL]    43.00
# AAGS2017010397000                            [RENSEIGNEMENTS CLIENT]     1.00
# AAGS2017010534300  [AUTRES TRAVAUX EN SOCIAL, FORMALITES DE LICEN...    31.25
# ACAB2017009616200  [COMPTABILITE GENERALE CABINET, DOCUMENTATION,...  2049.50
# ACAB2017009616300  [NON FACTURABLE SOCIAL, NON FACTURABLE COMPTAB...  2279.64
#
#                   valorisation_temps            site
#                                  sum        <lambda>
# code_mission
# AAGS2017010396900            5231.25      PITHIVIERS
# AAGS2017010397000              68.00            GIEN
# AAGS2017010534300            3868.00      PITHIVIERS
# ACAB2017009616200          222874.75  NON FACTURABLE
# ACAB2017009616300          151143.13  NON FACTURABLE

# %%
missions_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7921 entries, AAGS2017010396900 to ASST2017010135000
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   (mission, <lambda>)          7921 non-null   object
#  1   (exercice, <lambda>)         7921 non-null   int64
#  2   (code_client, <lambda>)      7921 non-null   object
#  3   (code_assistant, nunique)    7921 non-null   int64
#  4   (manager, <lambda>)          7921 non-null   object
#  5   (code_article, <lambda>)     7921 non-null   object
#  6   (libelle_article, <lambda>)  7921 non-null   object
#  7   (temps, sum)                 7921 non-null   float64
#  8   (valorisation_temps, sum)    7921 non-null   float64
#  9   (site, <lambda>)             7921 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 680.7+ KB

# %% [markdown]
# ## Lecture du dossier facturation sur 2017
# Quel coût facturé au client ?

# %%
facturation = pd.read_csv("./Data/facturation_2017.txt", sep="\t")

# %%
facturation.head()
# Out:
#         Code mission Client  Exercice Mission  Total HT  Exercice.1  \
# 0  AJUR2017008787500  05955      2017     JUR     97,50        2017
# 1  AGEJ2017008907500  07653      2017     GEJ    830,00        2017
# 2  ACOM2017008058400  03851      2017     COM  1 210,00        2017
# 3  ACOM2017008058800  05949      2017     COM    710,00        2017
# 4  ACOM2017008058900  06043      2017     COM    505,00        2017
#
#          Date Nature  N° Pièce  Article  Qté facturée Prix unitaire  \
# 0  23/12/2015    FAC    647073      601             0        390,00
# 1  30/03/2016    FAC    650700      061             1        830,00
# 2  15/04/2016    FAC    650809  ACOMPTE             1      1 210,00
# 3  15/04/2016    FAC    650814  ACOMPTE             1        710,00
# 4  15/04/2016    FAC    650819  ACOMPTE             1        505,00
#
#    Numéro d'ordre                        Désignation Raison sociale  \
# 0               5  SECRETARIAT JURIDIQUE ACOMPTE N°1   CROC EXPRESS
# 1               1   FORMALITES DE CONSTITUTION DE LA    TAXI FLORAN
# 2               1          ACOMPTE PROVISIONNEL N° 1  VANDEKERKHOVE
# 3               1          ACOMPTE PROVISIONNEL N° 1          HENRY
# 4               1          ACOMPTE PROVISIONNEL N° 1            C3H
#
#    Unnamed: 15
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
facturation.dtypes
# Out:
# Code mission       object
# Client             object
# Exercice            int64
# Mission            object
# Total HT           object
# Exercice.1          int64
# Date               object
# Nature             object
# N° Pièce            int64
# Article            object
# Qté facturée        int64
# Prix unitaire      object
# Numéro d'ordre      int64
# Désignation        object
# Raison sociale     object
# Unnamed: 15       float64
# dtype: object

# %%
facturation[facturation['Exercice'].isna()]
# Out:
# Empty DataFrame
# Columns: [Code mission, Client, Exercice, Mission, Total HT, Exercice.1, Date, Nature, N° Pièce, Article, Qté facturée, Prix unitaire, Numéro d'ordre, Désignation, Raison sociale, Unnamed: 15]
# Index: []

# %%
facturation.isnull().sum()
# Out:
# Code mission          0
# Client                0
# Exercice              0
# Mission               0
# Total HT              0
# Exercice.1            0
# Date                  0
# Nature                0
# N° Pièce              0
# Article               0
# Qté facturée          0
# Prix unitaire         0
# Numéro d'ordre        0
# Désignation          22
# Raison sociale        0
# Unnamed: 15       36886
# dtype: int64

# %%
# Remplacer les valeurs catégorielles par des floats
facturation['Total HT'] = [str(x).replace(',', '.') for x in facturation['Total HT']]
facturation['Total HT'] = [re.sub('\s','',x) for x in facturation['Total HT']]
facturation['Total HT'] = pd.to_numeric(facturation['Total HT'])

# %%
facturation['Total HT'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Remplir les valeurs NaN par 0 dans le Total HT de la facturation

# %%
facturation.fillna(0, inplace=True)

# %%
facturation['Qté facturée'].value_counts().head(10)
# Out:
# 1    25150
# 2     3870
# 3     1818
# 4     1283
# 5      932
# 6      717
# 7      475
# 8      338
# 0      331
# 9      286
# Name: Qté facturée, dtype: int64

# %% [markdown]
# ## Agrégation du dataset facturation sur le code_mission pour sommer le total HT facturé au client sur une mission particulière

# %%
fact_agg = facturation.groupby(['Code mission']).agg({'Total HT':['sum']})

# %%
fact_agg.head()
# Out:
#                   Total HT
#                        sum
# Code mission
# AAGS2017010396900  4550.00
# AAGS2017010397000   750.00
# AAGS2017010534300  4804.20
# AANT2017009877900  2953.26
# AANT2017010071600  1390.73

# %% [markdown]
# Il existe plus de missions dans facturation que de missions dans le dataset mission ?

# %% [markdown]
# ## Concaténation du dataset facturation sur l'ensemble des missions

# %%
data = pd.concat([missions_agg, fact_agg], axis=1)

# %%
data.columns = ['mission','exercice','code_client','code_assistant','manager','code_article',
                'libelle_article','temps','valorisation_temps','site','facturation']

# %%
#294 factures à 0 euro
data.isna().sum()
# Out:
# mission               154
# exercice              154
# code_client           154
# code_assistant        154
# manager               154
# code_article          154
# libelle_article       154
# temps                 154
# valorisation_temps    154
# site                  154
# facturation           352
# dtype: int64

# %%
len(data.index)
# Out:
# 8075

# %%
#Remplacer NaN par 0 euro
data['facturation'].fillna(0, inplace=True)

# %%
#Le reste des valeurs nulles correspondent au facture sur des codes_missions qui n'existent pas dans le dataset missions
data.isna().sum()
# Out:
# mission               154
# exercice              154
# code_client           154
# code_assistant        154
# manager               154
# code_article          154
# libelle_article       154
# temps                 154
# valorisation_temps    154
# site                  154
# facturation             0
# dtype: int64

# %% [markdown]
# Il se peut que des missions ne soient pas terminées sur le millésime 2020 mais qu'il existe une facture
#
# Supprimer les 154 lignes ajoutées sans aucune donnée car une facture mais pas dans de code_mission dans le dataset missions

# %%
list_index = data[data['code_client'].isna()].index
len(list_index)
# Out:
# 154

# %%
list_index
# Out:
# Index(['AANT2017009877900', 'AANT2017010071600', 'AANT2017010082500',
#        'AANT2017010121400', 'AANT2017010232600', 'AANT2017010233200',
#        'AANT2017010435400', 'AANT2017010441700', 'AANT2017010453600',
#        'AANT2017010461200',
#        ...
#        'AGES2017011439600', 'AJUR2017008778800', 'AJUR2017009607800',
#        'AJUR2017009694300', 'AJUR2017009732700', 'AJUR2017009732800',
#        'AJUR2017009746400', 'AJUR2017012502600', 'ALOC2017010095900',
#        'ALOC2017010441500'],
#       dtype='object', length=154)

# %%
facturation.columns
# Out:
# Index(['Code mission', 'Client', 'Exercice', 'Mission', 'Total HT',
#        'Exercice.1', 'Date', 'Nature', 'N° Pièce', 'Article', 'Qté facturée',
#        'Prix unitaire', 'Numéro d'ordre', 'Désignation', 'Raison sociale',
#        'Unnamed: 15'],
#       dtype='object')

# %%
facturation[facturation['Code mission'] == 'AANT2017009877900']
# Out:
#           Code mission Client  Exercice Mission  Total HT  Exercice.1  \
# 697  AANT2017009877900  06791      2017     ANT   2953.26        2017
#
#            Date Nature  N° Pièce Article  Qté facturée Prix unitaire  \
# 697  16/11/2016    FAC    659958     001             1      2 953,26
#
#      Numéro d'ordre                 Désignation          Raison sociale  \
# 697               1  REGULARISATION ANTERIORITE  LES TRESORS DE NEPTUNE
#
#      Unnamed: 15
# 697          0.0

# %%
data.drop(list_index, axis=0, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7921 entries, AAGS2017010396900 to ASST2017010135000
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mission             7921 non-null   object
#  1   exercice            7921 non-null   float64
#  2   code_client         7921 non-null   object
#  3   code_assistant      7921 non-null   float64
#  4   manager             7921 non-null   object
#  5   code_article        7921 non-null   object
#  6   libelle_article     7921 non-null   object
#  7   temps               7921 non-null   float64
#  8   valorisation_temps  7921 non-null   float64
#  9   site                7921 non-null   object
#  10  facturation         7921 non-null   float64
# dtypes: float64(5), object(6)
# memory usage: 742.6+ KB

# %%
data.head()
# Out:
#                   mission  exercice code_client  code_assistant  \
# AAGS2017010396900     AGS    2017.0       05782             2.0
# AAGS2017010397000     AGS    2017.0       06565             1.0
# AAGS2017010534300     AGS    2017.0       06924             2.0
# ACAB2017009616200     CAB    2017.0       09230            12.0
# ACAB2017009616300     CAB    2017.0       09000            98.0
#
#                           manager  \
# AAGS2017010396900             JOP
# AAGS2017010397000             FRL
# AAGS2017010534300             JOP
# ACAB2017009616200  NON FACTURABLE
# ACAB2017009616300  NON FACTURABLE
#
#                                                         code_article  \
# AAGS2017010396900                                              [029]
# AAGS2017010397000                                              [001]
# AAGS2017010534300                                    [029, 024, 001]
# ACAB2017009616200           [081, 096, 091, 079, 078, 082, 074, 088]
# ACAB2017009616300  [083, 082, 079, 096, 075, 010, 092, 080, 081, ...
#
#                                                      libelle_article    temps  \
# AAGS2017010396900                         [AUTRES TRAVAUX EN SOCIAL]    43.00
# AAGS2017010397000                            [RENSEIGNEMENTS CLIENT]     1.00
# AAGS2017010534300  [AUTRES TRAVAUX EN SOCIAL, FORMALITES DE LICEN...    31.25
# ACAB2017009616200  [COMPTABILITE GENERALE CABINET, DOCUMENTATION,...  2049.50
# ACAB2017009616300  [NON FACTURABLE SOCIAL, NON FACTURABLE COMPTAB...  2279.64
#
#                    valorisation_temps            site  facturation
# AAGS2017010396900             5231.25      PITHIVIERS       4550.0
# AAGS2017010397000               68.00            GIEN        750.0
# AAGS2017010534300             3868.00      PITHIVIERS       4804.2
# ACAB2017009616200           222874.75  NON FACTURABLE          0.0
# ACAB2017009616300           151143.13  NON FACTURABLE          0.0

# %% [markdown]
# ## Ajouter les entrées et sorties des clients MCCM

# %%
clients = pd.read_csv("./Data/client_dates.csv", sep=";")

# %%
clients_formes = pd.read_csv("./Data/client-naf-forme.csv", sep=";")

# %%
clients.head()
# Out:
#   Code Date création Départ cabinet
# 0   30    07/11/1995              0
# 1   44    31/10/1995              0
# 2  441    30/10/1995              0
# 3  455    07/11/1995              0
# 4  549    09/11/1995              0

# %%
clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11281 entries, 0 to 11280
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Code            11281 non-null  object
#  1   Date création   11277 non-null  object
#  2   Départ cabinet  11281 non-null  object
# dtypes: object(3)
# memory usage: 264.5+ KB

# %%
clients.dtypes
# Out:
# Code              object
# Date création     object
# Départ cabinet    object
# dtype: object

# %%
def entree_sortie(col):
    
    for date in str(col):
        if '2017' in str(col):
            return 1
        else:
            return 0

# %%
#Test de la fonction
entree_sortie("20/02/2017")
# Out:
# 1

# %%
clients['entrée_clt'] = clients['Date création'].apply(entree_sortie)

# %%
clients['sortie_clt'] = clients['Départ cabinet'].apply(entree_sortie)

# %%
clients.head(50)
# Out:
#     Code Date création Départ cabinet  entrée_clt  sortie_clt
# 0     30    07/11/1995              0           0           0
# 1     44    31/10/1995              0           0           0
# 2    441    30/10/1995              0           0           0
# 3    455    07/11/1995              0           0           0
# 4    549    09/11/1995              0           0           0
# 5    569    06/11/1995              0           0           0
# 6    579    06/11/1995     31/03/2020           0           0
# 7    584    10/11/1995              0           0           0
# 8    613    16/11/1995              0           0           0
# 9    632    30/10/1995              0           0           0
# 10   656    06/11/1995              0           0           0
# 11   666    03/11/1995              0           0           0
# 12   676    31/10/1995              0           0           0
# 13   685    03/11/1995              0           0           0
# 14   689    15/02/1996              0           0           0
# 15   707    03/11/1995              0           0           0
# 16   713    30/10/1995     15/12/2020           0           0
# 17   795    31/10/1995              0           0           0
# 18   952    06/11/1995              0           0           0
# 19   961    06/11/1995              0           0           0
# 20  1065    31/10/1995              0           0           0
# 21  1078    03/11/1995              0           0           0
# 22  1088    03/11/1995              0           0           0
# 23  1169    30/10/1995              0           0           0
# 24  1221    31/10/1995              0           0           0
# 25  1259    31/10/1995              0           0           0
# 26  1318    30/10/1995              0           0           0
# 27  1349    06/11/1995              0           0           0
# 28  1350    31/10/1995              0           0           0
# 29  1353    31/10/1995              0           0           0
# 30  1369    10/11/1995              0           0           0
# 31  1395    31/10/1995              0           0           0
# 32  1398    06/11/1995              0           0           0
# 33  1412    31/10/1995              0           0           0
# 34  1413    10/11/1995              0           0           0
# 35  1420    08/01/1996              0           0           0
# 36  1426    31/10/1995              0           0           0
# 37  1440    08/11/1995              0           0           0
# 38  1467    06/11/1995              0           0           0
# 39  1476    28/02/1996              0           0           0
# 40  1489    03/11/1995              0           0           0
# 41  1498    06/11/1995              0           0           0
# 42  1509    17/11/1995              0           0           0
# 43  1534    31/10/1995              0           0           0
# 44  1570    31/10/1995              0           0           0
# 45  1590    08/11/1995              0           0           0
# 46  1602    03/11/1995              0           0           0
# 47  1626    31/10/1995              0           0           0
# 48  1629    06/11/1995              0           0           0
# 49  1650    05/04/1996              0           0           0

# %%
clients.columns
# Out:
# Index(['Code', 'Date création', 'Départ cabinet', 'entrée_clt', 'sortie_clt'], dtype='object')

# %%
clients.columns = ['code_client', 'ENTREE_CLIENT', 'SORTIE_CLIENT', 'entrée_clt', 'sortie_clt']

# %%
clients.code_client.value_counts()
# Out:
# 2498      1
# 8936      1
# 6008      1
# A1619     1
# TESTA1    1
#          ..
# 6715      1
# 7743      1
# 6426      1
# 2810      1
# 2241      1
# Name: code_client, Length: 11281, dtype: int64

# %%
clients_formes.head()
# Out:
#   Code                                           Code NAF Forme juridique
# 0    9                                             Divers              SA
# 1   25                          Autre imprimerie (labeur)            SARL
# 2   26                   Édition de revues et périodiques              SA
# 3   30                  Fabrication de parquets assemblés             SAS
# 4   36  Commerce de détail d'habillement en magasin sp...            SARL

# %% [markdown]
# ## Concaténer les entrées et les sorties au dataset selon le code_client avec la fonction merge()

# %%
clients.code_client
# Out:
# 0           30
# 1           44
# 2          441
# 3          455
# 4          549
#          ...
# 11276    P7129
# 11277    P7503
# 11278    P7540
# 11279    P7673
# 11280    P7911
# Name: code_client, Length: 11281, dtype: object

# %%
len(clients.code_client[0])
# Out:
# 2

# %%
def suppr_0(s):
    return s.lstrip("0")

# %%
#Test de la suppression de 0 au début des identifiants
suppr_0("06565")
# Out:
# '6565'

# %%
data.code_client = data.code_client.apply(suppr_0)

# %%
data.head()
# Out:
#                   mission  exercice code_client  code_assistant  \
# AAGS2017010396900     AGS    2017.0        5782             2.0
# AAGS2017010397000     AGS    2017.0        6565             1.0
# AAGS2017010534300     AGS    2017.0        6924             2.0
# ACAB2017009616200     CAB    2017.0        9230            12.0
# ACAB2017009616300     CAB    2017.0        9000            98.0
#
#                           manager  \
# AAGS2017010396900             JOP
# AAGS2017010397000             FRL
# AAGS2017010534300             JOP
# ACAB2017009616200  NON FACTURABLE
# ACAB2017009616300  NON FACTURABLE
#
#                                                         code_article  \
# AAGS2017010396900                                              [029]
# AAGS2017010397000                                              [001]
# AAGS2017010534300                                    [029, 024, 001]
# ACAB2017009616200           [081, 096, 091, 079, 078, 082, 074, 088]
# ACAB2017009616300  [083, 082, 079, 096, 075, 010, 092, 080, 081, ...
#
#                                                      libelle_article    temps  \
# AAGS2017010396900                         [AUTRES TRAVAUX EN SOCIAL]    43.00
# AAGS2017010397000                            [RENSEIGNEMENTS CLIENT]     1.00
# AAGS2017010534300  [AUTRES TRAVAUX EN SOCIAL, FORMALITES DE LICEN...    31.25
# ACAB2017009616200  [COMPTABILITE GENERALE CABINET, DOCUMENTATION,...  2049.50
# ACAB2017009616300  [NON FACTURABLE SOCIAL, NON FACTURABLE COMPTAB...  2279.64
#
#                    valorisation_temps            site  facturation
# AAGS2017010396900             5231.25      PITHIVIERS       4550.0
# AAGS2017010397000               68.00            GIEN        750.0
# AAGS2017010534300             3868.00      PITHIVIERS       4804.2
# ACAB2017009616200           222874.75  NON FACTURABLE          0.0
# ACAB2017009616300           151143.13  NON FACTURABLE          0.0

# %%
data[data['code_client'] == '6087SAS'].index
# Out:
# Index(['ACOM2017009221900', 'ASOP2017010281600'], dtype='object')

# %%
data['code_client'].replace(['6087SAS'], '06087SAS', inplace=True)

# %%
data.reset_index(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7921 entries, 0 to 7920
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               7921 non-null   object
#  1   mission             7921 non-null   object
#  2   exercice            7921 non-null   float64
#  3   code_client         7921 non-null   object
#  4   code_assistant      7921 non-null   float64
#  5   manager             7921 non-null   object
#  6   code_article        7921 non-null   object
#  7   libelle_article     7921 non-null   object
#  8   temps               7921 non-null   float64
#  9   valorisation_temps  7921 non-null   float64
#  10  site                7921 non-null   object
#  11  facturation         7921 non-null   float64
# dtypes: float64(5), object(7)
# memory usage: 742.7+ KB

# %%
data_2017 = pd.merge(data, clients[['code_client','entrée_clt', 'sortie_clt']], how='left', on="code_client")

# %%
clients_formes.head()
# Out:
#   Code                                           Code NAF Forme juridique
# 0    9                                             Divers              SA
# 1   25                          Autre imprimerie (labeur)            SARL
# 2   26                   Édition de revues et périodiques              SA
# 3   30                  Fabrication de parquets assemblés             SAS
# 4   36  Commerce de détail d'habillement en magasin sp...            SARL

# %%
clients_formes.columns
# Out:
# Index(['Code', 'Code NAF', 'Forme juridique'], dtype='object')

# %%
clients_formes.columns = ['code_client', 'Code NAF', 'Forme juridique']

# %%
data_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7921 entries, 0 to 7920
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               7921 non-null   object
#  1   mission             7921 non-null   object
#  2   exercice            7921 non-null   float64
#  3   code_client         7921 non-null   object
#  4   code_assistant      7921 non-null   float64
#  5   manager             7921 non-null   object
#  6   code_article        7921 non-null   object
#  7   libelle_article     7921 non-null   object
#  8   temps               7921 non-null   float64
#  9   valorisation_temps  7921 non-null   float64
#  10  site                7921 non-null   object
#  11  facturation         7921 non-null   float64
#  12  entrée_clt          7921 non-null   int64
#  13  sortie_clt          7921 non-null   int64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 928.2+ KB

# %%
data_final_2017 = pd.merge(data_2017, clients_formes[['code_client', 'Code NAF','Forme juridique']], how='left', on="code_client")

# %%
data_final_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7921 entries, 0 to 7920
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               7921 non-null   object
#  1   mission             7921 non-null   object
#  2   exercice            7921 non-null   float64
#  3   code_client         7921 non-null   object
#  4   code_assistant      7921 non-null   float64
#  5   manager             7921 non-null   object
#  6   code_article        7921 non-null   object
#  7   libelle_article     7921 non-null   object
#  8   temps               7921 non-null   float64
#  9   valorisation_temps  7921 non-null   float64
#  10  site                7921 non-null   object
#  11  facturation         7921 non-null   float64
#  12  entrée_clt          7921 non-null   int64
#  13  sortie_clt          7921 non-null   int64
#  14  Code NAF            7921 non-null   object
#  15  Forme juridique     7921 non-null   object
# dtypes: float64(5), int64(2), object(9)
# memory usage: 1.0+ MB

# %%
#Vérification des valeurs nulles
data_final_2017.isna().sum()
# Out:
# index                 0
# mission               0
# exercice              0
# code_client           0
# code_assistant        0
# manager               0
# code_article          0
# libelle_article       0
# temps                 0
# valorisation_temps    0
# site                  0
# facturation           0
# entrée_clt            0
# sortie_clt            0
# Code NAF              0
# Forme juridique       0
# dtype: int64

# %%
#Vérification de combien de lignes par client
data_final_2017.code_client.value_counts()
# Out:
# 7406     7
# 7101     7
# A0554    6
# 7965     6
# 3262     6
#         ..
# 5012     1
# 7224     1
# 6833     1
# A0241    1
# A0465    1
# Name: code_client, Length: 4000, dtype: int64

# %%
data_final_2017[data_final_2017['code_client']=='5782']
# Out:
#                   index mission  exercice code_client  code_assistant manager  \
# 0     AAGS2017010396900     AGS    2017.0        5782             2.0     JOP
# 2091  ACOM2017009212800     COM    2017.0        5782             5.0     JOP
# 3786  AGE02017010748500     GE0    2017.0        5782             3.0     JOP
# 4568  AGES2017010232900     GES    2017.0        5782             4.0     JOP
# 6787  ASOP2017010235000     SOP    2017.0        5782            11.0     JOP
#
#                                            code_article  \
# 0                                                 [029]
# 2091  [049, 043, 016, 001, 011, 018, 041, 046, 044, ...
# 3786                               [049, 019, 029, 044]
# 4568                               [025, 027, 029, 024]
# 6787  [029, 021, 030, 022, 020, F0211, F02001, F0200...
#
#                                         libelle_article    temps  \
# 0                            [AUTRES TRAVAUX EN SOCIAL]    43.00
# 2091  [AUTRES TRAVAUX EXCEPTIONNELS, TABLEAU DE BORD...   173.50
# 3786  [AUTRES TRAVAUX EXCEPTIONNELS, PRESENTATION DE...    89.25
# 4568  [CONTRATS DE TRAVAIL, REPRESENTATION DU PERSON...    36.25
# 6787  [AUTRES TRAVAUX EN SOCIAL, DECLARATIONS MENSUE...  1011.25
#
#       valorisation_temps        site  facturation  entrée_clt  sortie_clt  \
# 0                5231.25  PITHIVIERS       4550.0           0           1
# 2091            22158.25  PITHIVIERS      24500.0           0           1
# 3786            13409.25  PITHIVIERS      13955.0           0           1
# 4568             2708.75  PITHIVIERS       2045.0           0           1
# 6787            27418.35  PITHIVIERS      17419.0           0           1
#
#                                                Code NAF Forme juridique
# 0     Fabrication de charpentes et d'autres menuiseries             SAS
# 2091  Fabrication de charpentes et d'autres menuiseries             SAS
# 3786  Fabrication de charpentes et d'autres menuiseries             SAS
# 4568  Fabrication de charpentes et d'autres menuiseries             SAS
# 6787  Fabrication de charpentes et d'autres menuiseries             SAS

# %%
data_final_2017.dtypes
# Out:
# index                  object
# mission                object
# exercice              float64
# code_client            object
# code_assistant        float64
# manager                object
# code_article           object
# libelle_article        object
# temps                 float64
# valorisation_temps    float64
# site                   object
# facturation           float64
# entrée_clt              int64
# sortie_clt              int64
# Code NAF               object
# Forme juridique        object
# dtype: object

# %%
#Supprimer les dossiers internes qui sont pour le cabinet et non facturable

# %%
data_final_2017[data_final_2017['type_mission'] == "SST"].index
# Out:
# Int64Index([7919, 7920], dtype='int64')

# %%
data_final_2017.drop([7919, 7920], axis=0, inplace=True)

# %% [markdown]
# ## Exportation du dataset 2017

# %%
data_final_2017.columns = ['code_mission', 'type_mission', 'exercice', 'code_client', 'total_assistant',
                           'manager', 'code_article', 'libelle_article', 'temps',
                           'valorisation_temps', 'site', 'facturation', 'entrée_clt', 'sortie_clt', 'secteur', 'forme']

# %%
data_final_2017.head()
# Out:
#         code_mission type_mission  exercice code_client  total_assistant  \
# 0  AAGS2017010396900          AGS    2017.0        5782              2.0
# 1  AAGS2017010397000          AGS    2017.0        6565              1.0
# 2  AAGS2017010534300          AGS    2017.0        6924              2.0
# 3  ACAB2017009616200          CAB    2017.0        9230             12.0
# 4  ACAB2017009616300          CAB    2017.0        9000             98.0
#
#           manager                                       code_article  \
# 0             JOP                                              [029]
# 1             FRL                                              [001]
# 2             JOP                                    [029, 024, 001]
# 3  NON FACTURABLE           [081, 096, 091, 079, 078, 082, 074, 088]
# 4  NON FACTURABLE  [083, 082, 079, 096, 075, 010, 092, 080, 081, ...
#
#                                      libelle_article    temps  \
# 0                         [AUTRES TRAVAUX EN SOCIAL]    43.00
# 1                            [RENSEIGNEMENTS CLIENT]     1.00
# 2  [AUTRES TRAVAUX EN SOCIAL, FORMALITES DE LICEN...    31.25
# 3  [COMPTABILITE GENERALE CABINET, DOCUMENTATION,...  2049.50
# 4  [NON FACTURABLE SOCIAL, NON FACTURABLE COMPTAB...  2279.64
#
#    valorisation_temps            site  facturation  entrée_clt  sortie_clt  \
# 0             5231.25      PITHIVIERS       4550.0           0           1
# 1               68.00            GIEN        750.0           0           0
# 2             3868.00      PITHIVIERS       4804.2           0           0
# 3           222874.75  NON FACTURABLE          0.0           0           0
# 4           151143.13  NON FACTURABLE          0.0           0           0
#
#                                              secteur        forme
# 0  Fabrication de charpentes et d'autres menuiseries          SAS
# 1                           Activités d'architecture         EURL
# 2     Fabrication de meubles de bureau et de magasin          SAS
# 3                                             Divers  Particulier
# 4                                             Divers  Particulier

# %%
data_final_2017.to_csv("./Data/dataset-2017.csv", index=False)
